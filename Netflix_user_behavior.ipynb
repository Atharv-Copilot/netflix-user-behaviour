# %%
# Netflix User Behavior Analysis

## Project Overview
This project analyzes Netflix user behavior data to understand viewer preferences, watch patterns, subscription trends, and engagement levels. The goal is to transform raw user data into meaningful insights through data analysis and visualization.

## Objective
To identify patterns in Netflix user activity and discover factors that influence viewing behavior, content preferences, and user engagement.

## Dataset Features
- Age
- Gender
- Country
- Subscription Type
- Monthly Fee
- Favorite Genre
- Average Watch Time
- Watch Sessions Per Week
- Binge Watch Sessions
- Completion Rate
- Rating Given
- Content Interactions
- Recommendation Click Rate
- Days Since Last Login
- Churn Status

## Technologies Used
- Python
- Pandas
- NumPy
- Matplotlib
- Seaborn

## Analysis Performed
- Data Cleaning and Preprocessing
- Exploratory Data Analysis (EDA)
- Genre Preference Analysis
- Subscription Type Analysis
- Watch Time Distribution
- User Engagement Analysis
- Correlation Analysis
- Data Visualization

## Visualizations
- Favorite Genre Distribution
- Subscription Type Distribution
- Watch Time Histogram
- User Rating Analysis
- Correlation Heatmap
- Country-wise User Distribution

## Key Findings
- Identified the most popular genres among users.
- Analyzed subscription plan preferences.
- Examined average watch time and binge-watching behavior.
- Explored relationships between engagement metrics and user ratings.
- Generated insights to support content recommendation strategies.

## Project Structure

Netflix_User_Behavior_Analysis/
│
├── netflix_user_behavior.csv
├── Netflix_User_Behavior_Analysis.ipynb
├── README.md
└── images/

## Results
The analysis provides valuable insights into user viewing habits, helping understand audience preferences and engagement patterns on Netflix.

## Future Improvements
- Build recommendation models.
- Predict customer churn.
- Perform advanced user segmentation.
- Create interactive dashboards using Power BI or Plotly.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (8807, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='type', data=df)
plt.title("Movies vs TV Shows")
plt.show()

# %%
genres = df['listed_in'].str.split(', ').explode()

plt.figure(figsize=(10,5))
genres.value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Genres on Netflix")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.show()

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

df['year_added'] = df['date_added'].dt.year

plt.figure(figsize=(10,5))
df['year_added'].value_counts().sort_index().plot()
plt.title("Content Added Over Years")
plt.xlabel("Year")
plt.ylabel("Number of Titles")
plt.show()

# %%
countries = df['country'].str.split(', ').explode()

plt.figure(figsize=(10,5))
countries.value_counts().head(10).plot(kind='bar')
plt.title("Top Countries Producing Netflix Content")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(y='rating', data=df,
              order=df['rating'].value_counts().index)
plt.title("Ratings Distribution")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['release_year'], bins=30)
plt.title("Release Year Distribution")
plt.show()
